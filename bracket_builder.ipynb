# %%
from entities import *
from simulations import *
from tournament_roster import *
from constants import TEAMS_DATA, STAT_EFFECTS

import pickle
import numpy as np
import pandas as pd
import openpyxl as xl

# %%
with open(TEAMS_DATA, 'rb') as f:
    teams = pickle.load(f)

with open(STAT_EFFECTS, 'rb') as f:
    stats = pickle.load(f)

# %%
simulate_game(teams['Alabama A&M'], teams['Air Force'])
# Out:
# {'Winner': 'Air Force',
#  'Winner Score': 74.68951650772706,
#  'Loser': 'Alabama A&M',
#  'Loser Score': 57.324239712631815,
#  'Game Log': [{'Kintavious Dozier': [15.736257038346825,
#     -0.8177101016971662,
#     {'2P': 4.810616287106715,
#      '3P': 0.8619131896123612,
#      'BLK': 0.1998871033423843,
#      'STL': 2.398645240108612,
#      'TOV': 2.2653871712136886,
#      'ORB': 1.199322620054306,
#      'DRB': 3.5979678601629175,
#      'PF': 2.2653871712136886}],
#    'Koron Davis': [16.047676636425884,
#     -0.5073928846022326,
#     {'2P': 4.040384648894062,
#      '3P': 0.9206799979950221,
#      'BLK': 0.1998871033423843,
#      'STL': 1.265951654501767,
#      'TOV': 2.198758136766227,
#      'ORB': 2.198758136766227,
#      'DRB': 6.796161513641065,
#      'PF': 4.397516273532454}],
#    'Louis Hutchinson': [9.763377926947124,
#     1.4571026797564044,
#     {'2P': 1.1398895213271703,
#      '3P': 2.007399549833118,
#      'BLK': 0.26651613778984573,
# ...

# %%
wb = xl.load_workbook('resources/blank_bracket.xlsx')

# %%
def first_round(region: dict):
    
    winners = []

    for pairing in first_round_order:
        game = simulate_game(teams[region[pairing[0]]], teams[region[pairing[1]]])
        winners.append(game['Winner'])

    return winners

# %%
first_round(east)
# Out:
# ['Abilene Christian',
#  'Alabama',
#  'Alabama State',
#  'Albany (NY)',
#  'Appalachian State',
#  'Arizona',
#  'Arkansas',
#  'Army']
