# %%
from entities import *
from simulations import *
from constants import TEAMS_DATA, STAT_EFFECTS

import pickle
import numpy as np
import pandas as pd

# %%
with open(TEAMS_DATA, 'rb') as f:
    teams = pickle.load(f)

with open(STAT_EFFECTS, 'rb') as f:
    stats = pickle.load(f)

# %%
from tournament_roster import *

simulate_game(teams[west[2]], teams[west[15]])
# Out:
# {'Winner': 'Arizona',
#  'Winner Score': 85.80314453004232,
#  'Loser': 'Long Beach State',
#  'Loser Score': 42.213406018840416,
#  'Game Log': [{'Addison Arnold': [4.319673866115979,
#     7.11452593988192,
#     {'2P': 2.937468520739447,
#      '3P': 0.0,
#      'BLK': 2.9076465053004674,
#      'STL': 0.0,
#      'TOV': 5.889848049198383,
#      'ORB': 5.889848049198383,
#      'DRB': 2.9076465053004674,
#      'PF': 5.889848049198383}],
#    "Anthony Dell'Orso": [16.292347214614157,
#     0.6751991543746367,
#     {'2P': 3.5544860201719253,
#      '3P': 2.5001286643268172,
#      'BLK': 0.4473302315846873,
#      'STL': 1.8638759649361971,
#      'TOV': 2.683981389508124,
#      'ORB': 0.4473302315846873,
#      'DRB': 2.683981389508124,
#      'PF': 2.3112061965208848}],
#    'Brayden Burries': [17.143421483619903,
#     0.43396323032840156,
#     {'2P': 4.484112796443504,
#      '3P': 1.7445879031802802,
#      'BLK': 0.5964403087795831,
#      'STL': 2.534871312313228,
#      'TOV': 3.1313116210928116,
#      'ORB': 0.5964403087795831,
#      'DRB': 3.8768620070672903,
#      'PF': 3.2804216982877072}],
#    'Dwayne Aristode': [17.630083788959023,
#     -0.6663025836981169,
#     {'2P': 1.8284623216024096,
#      '3P': 3.685553778026239,
#      'BLK': 0.0,
#      'STL': 0.5964403087795831,
#      'TOV': 0.8946604631693746,
#      'ORB': 1.8638759649361971,
#      'DRB': 3.354976736885155,
#      'PF': 1.8638759649361971}],
#    'Tobe Awaka': [25.63469545190882,
#     -3.657271819571781,
#     {'2P': 7.420612101681183,
#      '3P': 0.2609426350910676,
#      'BLK': 1.341990694754062,
#      'STL': 1.0437705403642703,
#      'TOV': 3.7277519298723942,
#      'ORB': 8.201054245719268,
#      'DRB': 12.972576715955931,
#      'PF': 5.815293010600935}]},
#   {'Cole Farrell': [5.749066696971382,
#     0.543376977144086,
#     {'2P': 1.860144900808133,
#      '3P': 0.37173159488571805,
#      'BLK': 0.0,
#      'STL': 0.37173159488571805,
#      'TOV': 1.1151947846571542,
#      'ORB': 1.4869263795428722,
#      'DRB': 1.4869263795428722,
#      'PF': 1.1151947846571542}],
#    'Gavin Sykes': [13.303016341665177,
#     0.04171680181949683,
#     {'2P': 3.7158290224776374,
#      '3P': 1.8601449008081332,
#      'BLK': 0.0,
#      'STL': 0.0,
#      'TOV': 0.7434631897714361,
#      'ORB': 0.37173159488571805,
#      'DRB': 1.1151947846571542,
#      'PF': 0.37173159488571805}],
#    'Isaiah Lewis': [1.5545339470499635,
#     3.7707953456346317,
#     {'2P': 0.37247505807548953,
#      '3P': 0.37173159488571805,
#      'BLK': 0.37173159488571805,
#      'STL': 0.7434631897714361,
#      'TOV': 1.4869263795428722,
#      'ORB': 0.0,
#      'DRB': 0.37173159488571805,
#      'PF': 3.3455843539714625}],
#    'Petar Majstorovic': [12.676817615781514,
#     0.05455784587447399,
#     {'2P': 1.8579145112388187,
#      '3P': 1.8605166324030191,
#      'BLK': 0.0,
#      'STL': 1.4869263795428722,
#      'TOV': 0.7434631897714361,
#      'ORB': 0.7434631897714361,
#      'DRB': 2.9738527590857444,
#      'PF': 2.9738527590857444}],
#    'Shaquil Bender': [5.029857496057319,
#     0.3724757543517478,
#     {'2P': 1.861631827187676,
#      '3P': 0.37173159488571805,
#      'BLK': 0.0,
#      'STL': 0.0,
#      'TOV': 0.7434631897714361,
#      'ORB': 1.1151947846571542,
#      'DRB': 0.7434631897714361,
#      'PF': 0.37173159488571805}]}]}

# %%
import openpyxl as xl

wb = xl.load_workbook('resources/blank_bracket.xlsx')
# Out:
# 'Seed'

# %%
from tournament_roster import *

# def first_round(region: dict):
    
#     winners = []

#     for pairing in first_round_order:
#         winners.append(simulate_game(region[pairing[0]], region[pairing[1]]))

#     seeds = [get_key(region, winner) for winner in winners]
#     next_round = list(np.resize(seeds, (4,2)))

#     return winners
