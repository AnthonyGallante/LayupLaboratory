# %%
from entities import *
from simulations import *
from tournament_roster import *
from constants import TEAMS_DATA, STAT_EFFECTS

import pickle
import numpy as np
import pandas as pd

# %%
with open(TEAMS_DATA, 'rb') as f:
    teams = pickle.load(f)

with open(STAT_EFFECTS, 'rb') as f:
    stats = pickle.load(f)

# %%
simulate_game(teams[west[8]], teams[west[9]])
# Out:
# {'Winner': 'Georgia',
#  'Winner Score': 106.19593904286148,
#  'Loser': 'Gonzaga',
#  'Loser Score': 71.21716037542697,
#  'Game Log': [{'Braeden Smith': [12.85911516681809,
#     -2.335778398736814,
#     {'2P': 2.3721940532514583,
#      '3P': 0.9450369261667477,
#      'BLK': 0.0,
#      'STL': 3.313540899779815,
#      'TOV': 2.8616944134462035,
#      'ORB': 0.22592324316680554,
#      'DRB': 5.648081079170138,
#      'PF': 2.635771170279398}],
#    'Emmanuel Innocenti': [15.895290929540488,
#     0.6430565222145752,
#     {'2P': 2.7653004963616996,
#      '3P': 2.158696588458827,
#      'BLK': 0.0,
#      'STL': 1.2802317112785646,
#      'TOV': 1.2802317112785646,
#      'ORB': 2.1086169362235183,
#      'DRB': 4.0666183770025,
#      'PF': 3.840695133835694}],
#    'Mario Saint-Supery': [16.803718517265608,
#     -0.9003040348770184,
#     {'2P': 1.844663280456967,
#      '3P': 2.785181741760379,
#      'BLK': 0.15061549544453703,
#      'STL': 3.1629254043352777,
#      'TOV': 2.937002161168472,
#      'ORB': 1.1296162158340277,
#      'DRB': 4.970311349669721,
#      'PF': 3.313540899779815}],
#    'Noah Haaland': [16.82920829335191,
#     -0.5356970051301699,
#     {'2P': 4.470493828037027,
#      '3P': 0.0,
#      'BLK': 0.0,
#      'STL': 2.2592324316680554,
#      'TOV': 2.2592324316680554,
#      'ORB': 2.2592324316680554,
#      'DRB': 8.961621978949953,
#      'PF': 6.702389547281898}],
#    'Steele Venters': [17.47656333816647,
#     -0.0651131250830792,
#     {'2P': 0.9460159268871371,
#      '3P': 4.0991513240185204,
#      'BLK': 0.22592324316680554,
#      'STL': 2.4098479271125925,
#      'TOV': 1.9580014407789814,
#      'ORB': 0.4518464863336111,
#      'DRB': 3.1629254043352777,
#      'PF': 2.8616944134462035}]},
#   {'Blue Cain': [26.233385574884334,
#     -4.305452152519434,
#     {'2P': 5.241236536729533,
#      '3P': 2.8745928890332664,
#      'BLK': 0.3028916167781746,
#      'STL': 2.8774703593926585,
#      'TOV': 1.2115664671126984,
#      'ORB': 2.8774703593926585,
#      'DRB': 5.754940718785317,
#      'PF': 2.044518413252679}],
#    'Dylan James': [18.53879509558945,
#     -3.639383611901522,
#     {'2P': 5.318095284486995,
#      '3P': 0.0,
#      'BLK': 1.287289371307242,
#      'STL': 2.801747455198115,
#      'TOV': 3.5589764971435516,
#      'ORB': 4.089036826505358,
#      'DRB': 9.162471407539782,
#      'PF': 4.089036826505358}],
#    'Jeremiah Wilkinson': [27.57044652961456,
#     -1.9231909749918472,
#     {'2P': 5.743733728964525,
#      '3P': 3.8383940136214174,
#      'BLK': 0.7572290419454365,
#      'STL': 4.013313922310814,
#      'TOV': 2.2716871258363094,
#      'ORB': 0.9843977545290675,
#      'DRB': 2.8774703593926585,
#      'PF': 2.120241317447222}],
#    'Justin Bailey': [19.223810086534087,
#     1.1530921003630938,
#     {'2P': 1.097982110820883,
#      '3P': 4.158096115130781,
#      'BLK': 0.0,
#      'STL': 1.968795509058135,
#      'TOV': 1.1358435629181547,
#      'ORB': 1.1358435629181547,
#      'DRB': 4.164759730699901,
#      'PF': 4.997711676839881}],
#    'Marcus Millender': [17.823337797851547,
#     0.06819876933410507,
#     {'2P': 3.337335556566123,
#      '3P': 2.7647946779511776,
#      'BLK': 0.0,
#      'STL': 2.7260245510035714,
#      'TOV': 3.331807784559921,
#      'ORB': 1.2115664671126984,
#      'DRB': 3.5589764971435516,
#      'PF': 2.3474100300308534}]}]}

# %%
import openpyxl as xl

wb = xl.load_workbook('resources/blank_bracket.xlsx')

# %%
from tournament_roster import *

# def first_round(region: dict):
    
#     winners = []

#     for pairing in first_round_order:
#         winners.append(simulate_game(region[pairing[0]], region[pairing[1]]))

#     seeds = [get_key(region, winner) for winner in winners]
#     next_round = list(np.resize(seeds, (4,2)))

#     return winners
